# %%
# import necessary libraries
import os
import pandas as pd

# %%
# setting directory and loading dataset
os.chdir(r"D:\Elevate labs internship\Task 1")
df=pd.read_csv("Medical.csv")

# %%
df.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# ...

# %%
df.shape
# Out:
# (110527, 14)

# %%
#checking datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  object
#  4   AppointmentDay  110527 non-null  object
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB

# %%
# drop unnecessary column
df.drop('PatientId',axis=1)
# Out:
#         AppointmentID Gender          ScheduledDay        AppointmentDay  Age  \
# 0             5642903      F  2016-04-29T18:38:08Z  2016-04-29T00:00:00Z   62
# 1             5642503      M  2016-04-29T16:08:27Z  2016-04-29T00:00:00Z   56
# 2             5642549      F  2016-04-29T16:19:04Z  2016-04-29T00:00:00Z   62
# 3             5642828      F  2016-04-29T17:29:31Z  2016-04-29T00:00:00Z    8
# 4             5642494      F  2016-04-29T16:07:23Z  2016-04-29T00:00:00Z   56
# ...               ...    ...                   ...                   ...  ...
# 110522        5651768      F  2016-05-03T09:15:35Z  2016-06-07T00:00:00Z   56
# 110523        5650093      F  2016-05-03T07:27:33Z  2016-06-07T00:00:00Z   51
# 110524        5630692      F  2016-04-27T16:03:52Z  2016-06-07T00:00:00Z   21
# 110525        5630323      F  2016-04-27T15:09:23Z  2016-06-07T00:00:00Z   38
# 110526        5629448      F  2016-04-27T13:30:56Z  2016-06-07T00:00:00Z   54
#
# ...

# %%
#checking number of null values in each column
df.isnull().sum()
# Out:
# PatientId         0
# AppointmentID     0
# Gender            0
# ScheduledDay      0
# AppointmentDay    0
# Age               0
# Neighbourhood     0
# Scholarship       0
# Hipertension      0
# Diabetes          0
# Alcoholism        0
# Handcap           0
# SMS_received      0
# No-show           0
# dtype: int64

# %%
#checking duplicated values in each column
df.duplicated().sum()
# Out:
# 0

# %%
#Converting column in proper format
df['Neighbourhood'].str.title()
# Out:
# 0           Jardim Da Penha
# 1           Jardim Da Penha
# 2             Mata Da Praia
# 3         Pontal De Camburi
# 4           Jardim Da Penha
#                 ...
# 110522          Maria Ortiz
# 110523          Maria Ortiz
# 110524          Maria Ortiz
# 110525          Maria Ortiz
# 110526          Maria Ortiz
# Name: Neighbourhood, Length: 110527, dtype: object

# %% [markdown]
# #### Converting data & time column to proper format

# %%
df['ScheduledDay']=df['ScheduledDay'].str.replace('T','')
df
# Out:
#            PatientId  AppointmentID Gender         ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-2918:38:08Z
# 1       5.589978e+14        5642503      M  2016-04-2916:08:27Z
# 2       4.262962e+12        5642549      F  2016-04-2916:19:04Z
# 3       8.679512e+11        5642828      F  2016-04-2917:29:31Z
# 4       8.841186e+12        5642494      F  2016-04-2916:07:23Z
# ...              ...            ...    ...                  ...
# 110522  2.572134e+12        5651768      F  2016-05-0309:15:35Z
# 110523  3.596266e+12        5650093      F  2016-05-0307:27:33Z
# 110524  1.557663e+13        5630692      F  2016-04-2716:03:52Z
# 110525  9.213493e+13        5630323      F  2016-04-2715:09:23Z
# 110526  3.775115e+14        5629448      F  2016-04-2713:30:56Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
df['ScheduledDay']=df['ScheduledDay'].str.replace('Z','')
df
# Out:
#            PatientId  AppointmentID Gender        ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-2918:38:08
# 1       5.589978e+14        5642503      M  2016-04-2916:08:27
# 2       4.262962e+12        5642549      F  2016-04-2916:19:04
# 3       8.679512e+11        5642828      F  2016-04-2917:29:31
# 4       8.841186e+12        5642494      F  2016-04-2916:07:23
# ...              ...            ...    ...                 ...
# 110522  2.572134e+12        5651768      F  2016-05-0309:15:35
# 110523  3.596266e+12        5650093      F  2016-05-0307:27:33
# 110524  1.557663e+13        5630692      F  2016-04-2716:03:52
# 110525  9.213493e+13        5630323      F  2016-04-2715:09:23
# 110526  3.775115e+14        5629448      F  2016-04-2713:30:56
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# 1       2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0
# ...

# %%
df['ScheduledDay']=pd.to_datetime(df['ScheduledDay'],format='%Y-%m-%d%H:%M:%S')
df
# Out:
#            PatientId  AppointmentID Gender        ScheduledDay  \
# 0       2.987250e+13        5642903      F 2016-04-29 18:38:08
# 1       5.589978e+14        5642503      M 2016-04-29 16:08:27
# 2       4.262962e+12        5642549      F 2016-04-29 16:19:04
# 3       8.679512e+11        5642828      F 2016-04-29 17:29:31
# 4       8.841186e+12        5642494      F 2016-04-29 16:07:23
# ...              ...            ...    ...                 ...
# 110522  2.572134e+12        5651768      F 2016-05-03 09:15:35
# 110523  3.596266e+12        5650093      F 2016-05-03 07:27:33
# 110524  1.557663e+13        5630692      F 2016-04-27 16:03:52
# 110525  9.213493e+13        5630323      F 2016-04-27 15:09:23
# 110526  3.775115e+14        5629448      F 2016-04-27 13:30:56
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# 1       2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0
# ...

# %%
df['AppointmentDay']=df['AppointmentDay'].str.replace('T','')
df
# Out:
#            PatientId  AppointmentID Gender        ScheduledDay  \
# 0       2.987250e+13        5642903      F 2016-04-29 18:38:08
# 1       5.589978e+14        5642503      M 2016-04-29 16:08:27
# 2       4.262962e+12        5642549      F 2016-04-29 16:19:04
# 3       8.679512e+11        5642828      F 2016-04-29 17:29:31
# 4       8.841186e+12        5642494      F 2016-04-29 16:07:23
# ...              ...            ...    ...                 ...
# 110522  2.572134e+12        5651768      F 2016-05-03 09:15:35
# 110523  3.596266e+12        5650093      F 2016-05-03 07:27:33
# 110524  1.557663e+13        5630692      F 2016-04-27 16:03:52
# 110525  9.213493e+13        5630323      F 2016-04-27 15:09:23
# 110526  3.775115e+14        5629448      F 2016-04-27 13:30:56
#
#              AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-2900:00:00Z   62    JARDIM DA PENHA            0
# 1       2016-04-2900:00:00Z   56    JARDIM DA PENHA            0
# ...

# %%
df['AppointmentDay']=df['AppointmentDay'].str.replace('Z','')
df
# Out:
#            PatientId  AppointmentID Gender        ScheduledDay  \
# 0       2.987250e+13        5642903      F 2016-04-29 18:38:08
# 1       5.589978e+14        5642503      M 2016-04-29 16:08:27
# 2       4.262962e+12        5642549      F 2016-04-29 16:19:04
# 3       8.679512e+11        5642828      F 2016-04-29 17:29:31
# 4       8.841186e+12        5642494      F 2016-04-29 16:07:23
# ...              ...            ...    ...                 ...
# 110522  2.572134e+12        5651768      F 2016-05-03 09:15:35
# 110523  3.596266e+12        5650093      F 2016-05-03 07:27:33
# 110524  1.557663e+13        5630692      F 2016-04-27 16:03:52
# 110525  9.213493e+13        5630323      F 2016-04-27 15:09:23
# 110526  3.775115e+14        5629448      F 2016-04-27 13:30:56
#
#             AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0       2016-04-2900:00:00   62    JARDIM DA PENHA            0             1
# ...

# %%
df['AppointmentDay']=pd.to_datetime(df['AppointmentDay'],format='%Y-%m-%d%H:%M:%S')
df
# Out:
#            PatientId  AppointmentID Gender        ScheduledDay AppointmentDay  \
# 0       2.987250e+13        5642903      F 2016-04-29 18:38:08     2016-04-29
# 1       5.589978e+14        5642503      M 2016-04-29 16:08:27     2016-04-29
# 2       4.262962e+12        5642549      F 2016-04-29 16:19:04     2016-04-29
# 3       8.679512e+11        5642828      F 2016-04-29 17:29:31     2016-04-29
# 4       8.841186e+12        5642494      F 2016-04-29 16:07:23     2016-04-29
# ...              ...            ...    ...                 ...            ...
# 110522  2.572134e+12        5651768      F 2016-05-03 09:15:35     2016-06-07
# 110523  3.596266e+12        5650093      F 2016-05-03 07:27:33     2016-06-07
# 110524  1.557663e+13        5630692      F 2016-04-27 16:03:52     2016-06-07
# 110525  9.213493e+13        5630323      F 2016-04-27 15:09:23     2016-06-07
# 110526  3.775115e+14        5629448      F 2016-04-27 13:30:56     2016-06-07
#
# ...

# %% [markdown]
# #### Checking data type to confirm data type of date and time column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  datetime64[ns]
#  4   AppointmentDay  110527 non-null  datetime64[ns]
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: datetime64[ns](2), float64(1), int64(8), object(3)
# memory usage: 11.8+ MB

# %% [markdown]
# ### Summary of data

# %%
df.describe()
# Out:
#           PatientId  AppointmentID                   ScheduledDay  \
# count  1.105270e+05   1.105270e+05                         110527
# mean   1.474963e+14   5.675305e+06  2016-05-09 07:49:15.846273024
# min    3.921784e+04   5.030230e+06            2015-11-10 07:13:56
# 25%    4.172614e+12   5.640286e+06            2016-04-29 10:27:01
# 50%    3.173184e+13   5.680573e+06            2016-05-10 12:13:17
# 75%    9.439172e+13   5.725524e+06            2016-05-20 11:18:37
# max    9.999816e+14   5.790484e+06            2016-06-08 20:07:23
# std    2.560949e+14   7.129575e+04                            NaN
#
#                       AppointmentDay            Age    Scholarship  \
# count                         110527  110527.000000  110527.000000
# mean   2016-05-19 00:57:50.008233472      37.088874       0.098266
# min              2016-04-29 00:00:00      -1.000000       0.000000
# 25%              2016-05-09 00:00:00      18.000000       0.000000
# ...
